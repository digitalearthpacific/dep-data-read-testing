# %%
from pystac_client import Client
from odc.stac import load
from planetary_computer import sign_url

from config import EXTENT_SMALL, DATES, LOAD_ARGS

# %%
client = Client.open("https://planetarycomputer.microsoft.com/api/stac/v1")

items = list(client.search(
    bbox=EXTENT_SMALL,
    datetime=DATES,
    collections=["sentinel-2-l2a"]
).items())

print(f"Found {len(items)} items")
# Out:
# Found 6 items

# %%
data = load(
    items,
    bbox=EXTENT_SMALL,
    patch_url=sign_url,
    bands=["B04", "B03", "B02", "SCL"],
    **LOAD_ARGS
)
data
# Out:
# <xarray.Dataset>
# Dimensions:      (y: 3357, x: 3127, time: 6)
# Coordinates:
#   * y            (y) float64 7.544e+06 7.544e+06 ... 7.511e+06 7.511e+06
#   * x            (x) float64 6.543e+05 6.543e+05 ... 6.855e+05 6.856e+05
#     spatial_ref  int32 32758
#   * time         (time) datetime64[ns] 2023-01-03T23:09:09.024000 ... 2023-01...
# Data variables:
#     B04          (time, y, x) float32 dask.array<chunksize=(1, 2048, 2048), meta=np.ndarray>
#     B03          (time, y, x) float32 dask.array<chunksize=(1, 2048, 2048), meta=np.ndarray>
#     B02          (time, y, x) float32 dask.array<chunksize=(1, 2048, 2048), meta=np.ndarray>
#     SCL          (time, y, x) float32 dask.array<chunksize=(1, 2048, 2048), meta=np.ndarray>

# %%
loaded = data.compute()
