# %%
from pystac_client import Client
from odc.stac import load
from planetary_computer import sign_url

from config import EXTENT, DATES, LOAD_ARGS

# %%
client = Client.open("https://planetarycomputer.microsoft.com/api/stac/v1")

items = list(client.search(
    bbox=EXTENT,
    datetime=DATES,
    collections=["landsat-c2-l2"],
).items())


print(f"Found {len(items)} items")
# Out:
# Found 8 items

# %%
data = load(
    items,
    bbox=EXTENT,
    bands=["red", "green", "blue", "qa_pixel"],
    patch_url=sign_url,
    **LOAD_ARGS
)
data
# Out:
# <xarray.Dataset>
# Dimensions:      (y: 1119, x: 1043, time: 4)
# Coordinates:
#   * y            (y) float64 -2.456e+06 -2.456e+06 ... -2.489e+06 -2.489e+06
#   * x            (x) float64 6.543e+05 6.543e+05 ... 6.855e+05 6.856e+05
#     spatial_ref  int32 32658
#   * time         (time) datetime64[ns] 2023-01-01T22:51:32.307040 ... 2023-01...
# Data variables:
#     red          (time, y, x) uint16 dask.array<chunksize=(1, 1119, 1043), meta=np.ndarray>
#     green        (time, y, x) uint16 dask.array<chunksize=(1, 1119, 1043), meta=np.ndarray>
#     blue         (time, y, x) uint16 dask.array<chunksize=(1, 1119, 1043), meta=np.ndarray>
#     qa_pixel     (time, y, x) uint16 dask.array<chunksize=(1, 1119, 1043), meta=np.ndarray>

# %%
# %%time

loaded = data.compute()
# Out:
# CPU times: user 10.2 s, sys: 273 ms, total: 10.5 s
# Wall time: 16.3 s
