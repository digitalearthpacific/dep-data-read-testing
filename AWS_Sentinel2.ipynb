# %%
from pystac_client import Client
from odc.stac import load

from config import EXTENT_SMALL, DATES, LOAD_ARGS

# %%
client = Client.open("https://earth-search.aws.element84.com/v1")

items = list(client.search(
    bbox=EXTENT_SMALL,
    datetime=DATES,
    collections=["sentinel-2-c1-l2a"]
).items())

print(f"Found {len(items)} items")
# Out:
# Found 8 items

# %%
data = load(
    items,
    bbox=EXTENT_SMALL,
    bands=["red", "green", "blue", "scl"],
    **LOAD_ARGS
)
data
# Out:
# <xarray.Dataset>
# Dimensions:      (y: 3357, x: 3127, time: 8)
# Coordinates:
#   * y            (y) float64 7.544e+06 7.544e+06 ... 7.511e+06 7.511e+06
#   * x            (x) float64 6.543e+05 6.543e+05 ... 6.855e+05 6.856e+05
#     spatial_ref  int32 32758
#   * time         (time) datetime64[ns] 2023-01-03T23:12:28.576000 ... 2023-01...
# Data variables:
#     red          (time, y, x) uint16 dask.array<chunksize=(1, 2048, 2048), meta=np.ndarray>
#     green        (time, y, x) uint16 dask.array<chunksize=(1, 2048, 2048), meta=np.ndarray>
#     blue         (time, y, x) uint16 dask.array<chunksize=(1, 2048, 2048), meta=np.ndarray>
#     scl          (time, y, x) uint8 dask.array<chunksize=(1, 2048, 2048), meta=np.ndarray>

# %%
# %%time

loaded = data.compute()
